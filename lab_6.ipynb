# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Retail_Dataset_Cleaned (2).csv")
print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
df.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     Bx_Pune_034    Brandx_India Superstore Pune  Brandx_India      Flagship
# 1   Bx_Mumbai_023  Brandx_India Superstore Mumbai  Brandx_India  Street Store
# 2     Bx_Pune_073        Brandx_India Trends Pune  Brandx_India      Flagship
# 3  Bx_Chennai_061     Brandx_India Trends Chennai  Brandx_India    Mall Store
# 4  Bx_Chennai_033    Brandx_India Connect Chennai  Brandx_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100G  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1Kg  Groceries            Sugar
# 2     Pune     Tier1   Levi'S T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    Playstation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ...  Brand_Loyalty  Brand_Awareness  Price_Competitiveness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5146 entries, 0 to 5145
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5146 non-null   object
#  1   Store_Name             5146 non-null   object
#  2   Brand_Name             5146 non-null   object
#  3   Store_Type             5146 non-null   object
#  4   City                   5146 non-null   object
#  5   City_Tier              5146 non-null   object
#  6   Product_Name           5146 non-null   object
#  7   Category               5146 non-null   object
#  8   Sub_Category           5146 non-null   object
#  9   Product_Stage          5146 non-null   object
#  10  Quantity_Available     5146 non-null   float64
#  11  Units_Sold             5146 non-null   float64
#  12  Unit_Price             5146 non-null   int64
#  13  Cost_Price             5146 non-null   int64
# ...

# %%
mean_revenue = df["Revenue"].mean()
print("Mean Revenue:",  mean_revenue)
# Out:
# Mean Revenue: 1376186.72813836

# %%
median_revenue = df["Revenue"].median()
print("Medain Revenue:", median_revenue)
# Out:
# Medain Revenue: 350176.0

# %%
comparison = pd.DataFrame({
    "Statistic": ["Mean Revenue", "Median Revenue"],
    "Value": [mean_revenue, median_revenue]
})
comparison
# Out:
#         Statistic         Value
# 0    Mean Revenue  1.376187e+06
# 1  Median Revenue  3.501760e+05

# %%
mean_units = df["Units_Sold"].mean()
print("Average Units Sold:", mean_units)
# Out:
# Average Units Sold: 44.40011659541391

# %%
median_delivery = df["Delivery_Time"].median()
print("Median Delivery Time:", median_delivery)
# Out:
# Median Delivery Time: 4.0

# %%
mode_category = df["Category"].mode()
print("Most Common Product Category:")
print(mode_category)
# Out:
# Most Common Product Category:
# 0    Electronics
# Name: Category, dtype: object

# %%
print("Mean Revenue:", mean_revenue)
print("Median Revenue:", median_revenue)
# Out:
# Mean Revenue: 1376186.72813836
# Median Revenue: 350176.0

# %%
df.describe()
# Out:
#        Quantity_Available   Units_Sold     Unit_Price     Cost_Price  \
# count         5146.000000  5146.000000    5146.000000    5146.000000
# mean           148.712204    44.400117   36200.123202   28052.458414
# std             60.791988    26.898171   53995.455582   41916.676567
# min             14.000000     4.000000      36.000000      28.000000
# 25%            100.000000    25.000000    2019.500000    1553.250000
# 50%            149.000000    40.000000   11825.500000    9174.500000
# 75%            195.000000    59.000000   53814.000000   41569.500000
# max            337.000000   154.000000  307651.000000  252171.000000
#
#             Revenue  Profit_Margin  Average_Order_Value  Inventory_Turnover  \
# count  5.146000e+03    5146.000000          5146.000000         5146.000000
# mean   1.376187e+06      22.448311         45071.163817            3.925367
# std    2.386996e+06       4.346833         67513.033478            2.281656
# ...

# %%
df[["Revenue",
"Profit_Margin"]].describe()
# Out:
#             Revenue  Profit_Margin
# count  5.146000e+03    5146.000000
# mean   1.376187e+06      22.448311
# std    2.386996e+06       4.346833
# min    8.400000e+02      14.680000
# 25%    5.184600e+04      18.670000
# 50%    3.501760e+05      22.430000
# 75%    1.770355e+06      26.220000
# max    2.334358e+07      30.430000

# %%
df[["Quantity_Available",
    "Units_Sold"]].describe()
# Out:
#        Quantity_Available   Units_Sold
# count         5146.000000  5146.000000
# mean           148.712204    44.400117
# std             60.791988    26.898171
# min             14.000000     4.000000
# 25%            100.000000    25.000000
# 50%            149.000000    40.000000
# 75%            195.000000    59.000000
# max            337.000000   154.000000

# %%
df[[
    "Customer_Satisfaction"
]].describe()
# Out:
#        Customer_Satisfaction
# count            5146.000000
# mean                4.209192
# std                 0.278632
# min                 3.600000
# 25%                 4.000000
# 50%                 4.200000
# 75%                 4.400000
# max                 4.900000

# %%
df.describe(include="all")
# Out:
#             Store_ID                      Store_Name    Brand_Name  \
# count           5146                            5146          5146
# unique          1179                             280             1
# top     Bx_Delhi_092  Brandx_India Gadget Zone Delhi  Brandx_India
# freq              20                              77          5146
# mean             NaN                             NaN           NaN
# std              NaN                             NaN           NaN
# min              NaN                             NaN           NaN
# 25%              NaN                             NaN           NaN
# 50%              NaN                             NaN           NaN
# 75%              NaN                             NaN           NaN
# max              NaN                             NaN           NaN
#
#         Store_Type   City City_Tier  Product_Name     Category Sub_Category  \
# count         5146   5146      5146          5146         5146         5146
# ...

# %%
revenue_range = (
    df["Revenue"].max() -
    df["Revenue"].min()
)

print("Revenue Range:", revenue_range)
# Out:
# Revenue Range: 23342742.0

# %%
revenue_std = df["Revenue"].std()

print("Revenue Standard Deviation:", revenue_std)
# Out:
# Revenue Standard Deviation: 2386995.7963298312

# %%
revenue_variance = df["Revenue"].var()

print("Revenue Variance:", revenue_variance)
# Out:
# Revenue Variance: 5697748931696.284

# %%
summary_table = pd.DataFrame({
    "Statistic": [
        "Mean Revenue",
        "Median Revenue",
        "Revenue Std Dev",
        "Revenue Variance"
    ],
    "Value": [
        df["Revenue"].mean(),
        df["Revenue"].median(),
        df["Revenue"].std(),
        df["Revenue"].var()
    ]
})

summary_table
# Out:
#           Statistic         Value
# 0      Mean Revenue  1.376187e+06
# 1    Median Revenue  3.501760e+05
# 2   Revenue Std Dev  2.386996e+06
# 3  Revenue Variance  5.697749e+12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5146 entries, 0 to 5145
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5146 non-null   object
#  1   Store_Name             5146 non-null   object
#  2   Brand_Name             5146 non-null   object
#  3   Store_Type             5146 non-null   object
#  4   City                   5146 non-null   object
#  5   City_Tier              5146 non-null   object
#  6   Product_Name           5146 non-null   object
#  7   Category               5146 non-null   object
#  8   Sub_Category           5146 non-null   object
#  9   Product_Stage          5146 non-null   object
#  10  Quantity_Available     5146 non-null   float64
#  11  Units_Sold             5146 non-null   float64
#  12  Unit_Price             5146 non-null   int64
#  13  Cost_Price             5146 non-null   int64
# ...
